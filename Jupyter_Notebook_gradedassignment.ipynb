# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# Final Assignment of the second course

# %% [markdown]
# Mark down of the introduction
# I am Muhammad Ammar Zaid. I pursue data science because of its rich mathematical compelexity and my desire to learn about probabilistic and algebraic methods that will help me optimise and make existing code more efficient.

# %% [markdown]
# Data science languages:
# Python
# R
# SQL
# Scala
# C/C++

# %% [markdown]
# Data science libraries:
# scikitlearn
# tensorflow
# numpy
# pytorch
# theano
# caffe

# %% [markdown]
# Data science tools:
# Matlab
# R studio
# Jupyter
# TensorFlow
# ApacheSpark

# %% [markdown]
# Arithmetic examples:
# 2+2=4

# %%
x = 2 * 2
y = 2 + 2
print(x)
print(y)

# %%
minutes=int(input("Enter minutes"))
h=minutes//60
minutes=minutes%60
print("Hours=",h)
print("Minutes=",m)

# %% [markdown]
# Ex10: My objective is to learn datascience and to become a proficient data scientist.

# %% [markdown]
# EX11: The author of this notebook is me, Muhammad Ammar Zaid
